# %%
from scipy import stats
import math
mu = 3173
sigma = 1120
x = 2700

z_score = (x - mu) / sigma
print(f'z_score: {z_score}')

p = stats.norm.cdf(z_score)
print(f'p: {p}')
# Out:
# z_score: -0.42232142857142857
# p: 0.3363952096371293

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

def draw_z_score(x, cond, mu=0, sigma=1):
    y = stats.norm.pdf(x, mu, sigma)
    z = x[cond]
    plt.plot(x,y)
    plt.fill_between(z,0,stats.norm.pdf(z,mu,sigma))
    plt.show()
    
x = np.arange(-3,3,0.001)
draw_z_score(x, x<z_score)

# %%
mu = 3173
sigma = 1120
x = 2700
n = 25

z_score = (x - mu) / (sigma / math.sqrt(n))
print(f'z_score: {z_score}')

p = stats.norm.cdf(z_score)
print(f'p: {p}')
# Out:
# z_score: -2.111607142857143
# p: 0.017360079699138387

# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt

def draw_z_score(x, cond, mu=0, sigma=1):
    y = stats.norm.pdf(x, mu, sigma)
    z = x[cond]
    plt.plot(x,y)
    plt.fill_between(z,0,stats.norm.pdf(z,mu,sigma))
    plt.show()
    
x = np.arange(-3,3,0.001)
draw_z_score(x, x<z_score)

# %%
# interpretasi x and x̄
# -walaupun hanya memiliki 34% kemungkinan untuk seorang undergraduate memiliki balance dibawah 2700 tetapi hanya 
# terdapat 2% kemungkinan untuk nilai mean dari sample 25 undergraduates yang memiliki balance dibawah 2700
# -untuk yang kedua termasuk unusual event karena hanya 2% saja kemungkinannya
